# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_209770_6.txt', sep=" ")
df.plot.scatter(x = 'x', y = 'y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
import seaborn as sns
df = pd.read_csv('genome_matrix (1).csv', index_col=0)
g = sns.heatmap(df, cmap='viridis')
g.xaxis.set_ticks_position('top')
g.xaxis.set_tick_params(rotation=90)

# %%
import ast


df = pd.read_csv('dota_hero_stats (1).csv')
df.head()
df["roles"] = df["roles"].apply(ast.literal_eval)
df['total_roles'] = df['roles'].apply(len)
df.hist()
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'id'}>],
#        [<Axes: title={'center': 'legs'}>,
#         <Axes: title={'center': 'total_roles'}>]], dtype=object)

# %%
df = pd.DataFrame()
df['type'] = ['A', 'A', 'B', 'B']
df['value'] = [10, 14,12,23]

columns = ['type', 'value']
data = [['A', 10], ['A', 14], ['B', 12], ['B', 23]]
my_data = pd.DataFrame(data = data, columns = columns)

my_data.iloc[0:1]
my_data.iloc[:, [1,3]].loc[(my_data.index != 1) & (my_data.index != 5)]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[50], line 10
#       7 my_data = pd.DataFrame(data = data, columns = columns)
#       9 my_data.iloc[0:1]
# ---> 10 my_data.iloc[:, [1,3]].loc[(my_data.index != 1) & (my_data.index != 5)]
#
# File c:\Users\alexx\PycharmProjects\HSE_HW\.venv\Lib\site-packages\pandas\core\indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File c:\Users\alexx\PycharmProjects\HSE_HW\.venv\Lib\site-packages\pandas\core\indexing.py:1691, in _iLocIndexer._getitem_tuple(self, tup)
#    1690 def _getitem_tuple(self, tup: tuple):
# ...
